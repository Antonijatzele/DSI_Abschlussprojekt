# %%
import json
import numpy as np
import pandas as pd

# %%
# Daten laden
with open("data.json", encoding="utf8") as f:
    in_json = f.read()
js = json.loads(in_json)
data = js["data"][0]

# Struktur laden
with open("structure.json", encoding="utf8") as f:
    in_json = f.read()
structure = json.loads(in_json)

# %%
# Erstellt aus den json-Daten ein Pandas Dataframe
def data2df(data, lng="de"):
    # Daten als Numpy-Array einladen
    arr = np.array(data["value"]).reshape(data["size"])

    # Array flatten und Indices anspeichern
    flat_arr = []
    for idx, subarray in np.ndenumerate(arr):
        # Addiere den Index und den Wert als Tuple
        flat_arr.append((idx, subarray))

    # Liste zur Übersetzung der Indices in Codes erstellen
    dim = []
    for cat in data["id"]:
        ind = data["dimension"][cat]["category"]["index"]
        ind_rev = {value: key for key, value in ind.items()}
        dim.append(ind_rev)

    # Incdies in Codes/Werte übersetzen und Tabelle erstellen
    table = []
    for x in flat_arr:
        row = []
        for i, j in enumerate(x[0]):
            if not data["id"][i] in ["statistic", "content"]:
                code = dim[i][j]
                val = structure["variableValues"][code]["label"][lng]
                row.append(code)
                row.append(val)
            
        row.append(int(x[1]))
        table.append(row)

    # Spaltennamen erstellen
    cols = [item for sublist in [[col, structure["variables"][col]["label"][lng]] for col in data["id"] if not col in ["statistic", "content"]] for item in sublist] + ["Value"]
    
    # Tabelle als DataFrame zurückgeben
    return pd.DataFrame(table, columns=cols)

# %%
df = data2df(data)
df
# Out:
#                STAG    Stichtag   GES Geschlecht       RECGL3  \
# 0        2024-12-31  31.12.2024  GESM   männlich  REC-EU-FZKB
# 1        2024-12-31  31.12.2024  GESM   männlich  REC-EU-FZKB
# 2        2024-12-31  31.12.2024  GESM   männlich  REC-EU-FZKB
# 3        2024-12-31  31.12.2024  GESM   männlich  REC-EU-FZKB
# 4        2024-12-31  31.12.2024  GESM   männlich  REC-EU-FZKB
# ...             ...         ...   ...        ...          ...
# 2574203  2024-12-31  31.12.2024  GESW   weiblich    REC-AT-05
# 2574204  2024-12-31  31.12.2024  GESW   weiblich    REC-AT-05
# 2574205  2024-12-31  31.12.2024  GESW   weiblich    REC-AT-05
# 2574206  2024-12-31  31.12.2024  GESW   weiblich    REC-AT-05
# 2574207  2024-12-31  31.12.2024  GESW   weiblich    REC-AT-05
#
#                            Ausgewählte Aufenthaltstitel    STAAG6  \
# 0                     Aufenthaltsrecht nach FreizügG/EU     ST287
# 1                     Aufenthaltsrecht nach FreizügG/EU     ST287
# 2                     Aufenthaltsrecht nach FreizügG/EU     ST287
# 3                     Aufenthaltsrecht nach FreizügG/EU     ST287
# 4                     Aufenthaltsrecht nach FreizügG/EU     ST287
# ...                                                 ...       ...
# 2574203  Ohne Aufenthaltstitel, Duldung oder Gestattung  STAAT900
# 2574204  Ohne Aufenthaltstitel, Duldung oder Gestattung  STAAT900
# 2574205  Ohne Aufenthaltstitel, Duldung oder Gestattung  STAAT900
# 2574206  Ohne Aufenthaltstitel, Duldung oder Gestattung  STAAT900
# 2574207  Ohne Aufenthaltstitel, Duldung oder Gestattung  STAAT900
#
#              Staatsangehörigkeit KREISE                          Kreise  Value
# 0                        Ägypten  01001     Flensburg, kreisfreie Stadt      0
# 1                        Ägypten  01002          Kiel, kreisfreie Stadt      0
# 2                        Ägypten  01003        Lübeck, kreisfreie Stadt      0
# 3                        Ägypten  01004    Neumünster, kreisfreie Stadt      0
# 4                        Ägypten  01051         Dithmarschen, Landkreis      0
# ...                          ...    ...                             ...    ...
# 2574203  Ungeklärt / Ohne Angabe  16073  Saalfeld-Rudolstadt, Landkreis      0
# 2574204  Ungeklärt / Ohne Angabe  16074            Saale-Holzland-Kreis      0
# 2574205  Ungeklärt / Ohne Angabe  16075                Saale-Orla-Kreis      0
# 2574206  Ungeklärt / Ohne Angabe  16076                Greiz, Landkreis      0
# 2574207  Ungeklärt / Ohne Angabe  16077     Altenburger Land, Landkreis      0
#
# [2574208 rows x 11 columns]

# %%
# Darstellung wie online
pd.pivot_table(
    df, 
    values=['Value'], 
    index=['KREISE', 'Staatsangehörigkeit'], 
    columns=['Ausgewählte Aufenthaltstitel','Geschlecht'], 
    aggfunc="sum"
)
# Out:
#                                                                   Value  \
# Ausgewählte Aufenthaltstitel Antrag auf einen Aufenthaltstitel gestellt
# Geschlecht                                                     männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                                   60
#        Albanien                                                      10
#        Algerien                                                       5
#        Andorra                                                        0
#        Angola                                                         0
# ...                                                                 ...
# 16077  Zypern                                                         0
#        Ägypten                                                        0
#        Äquatorialguinea                                               0
#        Äthiopien                                                      0
#        Österreich                                                     0
#
#                                                                       \
# Ausgewählte Aufenthaltstitel          Aufenthaltsgestattung
# Geschlecht                   weiblich              männlich weiblich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                 15                    25       15
#        Albanien                     5                     0        0
#        Algerien                     0                     0        5
#        Andorra                      0                     0        0
#        Angola                       0                     0        0
# ...                               ...                   ...      ...
# 16077  Zypern                       0                     0        0
#        Ägypten                      0                     0        0
#        Äquatorialguinea             0                     0        0
#        Äthiopien                    0                     0        0
#        Österreich                   0                     0        0
#
#                                                                          \
# Ausgewählte Aufenthaltstitel Aufenthaltsrecht nach FreizügG/EU
# Geschlecht                                            männlich weiblich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                           5        0
#        Albanien                                              0        5
#        Algerien                                              0        0
#        Andorra                                               0        0
#        Angola                                                0        0
# ...                                                        ...      ...
# 16077  Zypern                                                0        0
#        Ägypten                                               0        0
#        Äquatorialguinea                                      0        0
#        Äthiopien                                             0        0
#        Österreich                                           15       15
#
#                                                                                  \
# Ausgewählte Aufenthaltstitel Befristete AE, besondere Gründe und nationale Visa
# Geschlecht                                                             männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                                           10
#        Albanien                                                               5
#        Algerien                                                               0
#        Andorra                                                                0
#        Angola                                                                 0
# ...                                                                         ...
# 16077  Zypern                                                                 0
#        Ägypten                                                                0
#        Äquatorialguinea                                                       0
#        Äthiopien                                                              0
#        Österreich                                                             0
#
#                                        \
# Ausgewählte Aufenthaltstitel
# Geschlecht                   weiblich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                  0
#        Albanien                     0
#        Algerien                     0
#        Andorra                      0
#        Angola                       0
# ...                               ...
# 16077  Zypern                       0
#        Ägypten                      0
#        Äquatorialguinea             0
#        Äthiopien                    0
#        Österreich                   0
#
#                                                                                 \
# Ausgewählte Aufenthaltstitel Befristete AE, völkerrechtl., human., pol. Gründe
# Geschlecht                                                            männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                                         310
#        Albanien                                                              5
#        Algerien                                                              0
#        Andorra                                                               0
#        Angola                                                                0
# ...                                                                        ...
# 16077  Zypern                                                                0
#        Ägypten                                                               0
#        Äquatorialguinea                                                      0
#        Äthiopien                                                             0
#        Österreich                                                            0
#
#                                        ...  \
# Ausgewählte Aufenthaltstitel           ...
# Geschlecht                   weiblich  ...
# KREISE Staatsangehörigkeit             ...
# 01001  Afghanistan                180  ...
#        Albanien                     5  ...
#        Algerien                     0  ...
#        Andorra                      0  ...
#        Angola                       0  ...
# ...                               ...  ...
# 16077  Zypern                       0  ...
#        Ägypten                      0  ...
#        Äquatorialguinea             0  ...
#        Äthiopien                    0  ...
#        Österreich                   0  ...
#
#                                                                                 \
# Ausgewählte Aufenthaltstitel Befristete Aufenthaltserlaubnis, familiäre Gründe
# Geschlecht                                                            männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                                          25
#        Albanien                                                             10
#        Algerien                                                              5
#        Andorra                                                               0
#        Angola                                                                0
# ...                                                                        ...
# 16077  Zypern                                                                0
#        Ägypten                                                               5
#        Äquatorialguinea                                                      0
#        Äthiopien                                                             0
#        Österreich                                                            0
#
#                                                          \
# Ausgewählte Aufenthaltstitel           Duldung
# Geschlecht                   weiblich männlich weiblich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                 40       10        0
#        Albanien                    15        5        5
#        Algerien                    10        0        0
#        Andorra                      0        0        0
#        Angola                       0        0        0
# ...                               ...      ...      ...
# 16077  Zypern                       0        0        0
#        Ägypten                      5        0        0
#        Äquatorialguinea             0        0        0
#        Äthiopien                    0        0        0
#        Österreich                   0        0        0
#
#                                                                              \
# Ausgewählte Aufenthaltstitel Ohne Aufenthaltstitel, Duldung oder Gestattung
# Geschlecht                                                         männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                                       45
#        Albanien                                                           5
#        Algerien                                                           5
#        Andorra                                                            0
#        Angola                                                             0
# ...                                                                     ...
# 16077  Zypern                                                             0
#        Ägypten                                                            0
#        Äquatorialguinea                                                   0
#        Äthiopien                                                          0
#        Österreich                                                         0
#
#                                                                             \
# Ausgewählte Aufenthaltstitel          Unbefristete Niederlassungserlaubnis
# Geschlecht                   weiblich                             männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                 10                                  100
#        Albanien                     5                                   10
#        Algerien                     0                                    5
#        Andorra                      0                                    0
#        Angola                       0                                    0
# ...                               ...                                  ...
# 16077  Zypern                       0                                    0
#        Ägypten                      0                                    0
#        Äquatorialguinea             0                                    0
#        Äthiopien                    0                                    0
#        Österreich                   0                                    0
#
#                                        \
# Ausgewählte Aufenthaltstitel
# Geschlecht                   weiblich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                 15
#        Albanien                     5
#        Algerien                     0
#        Andorra                      0
#        Angola                       0
# ...                               ...
# 16077  Zypern                       0
#        Ägypten                      0
#        Äquatorialguinea             0
#        Äthiopien                    0
#        Österreich                   0
#
#                                                                               \
# Ausgewählte Aufenthaltstitel Vom Erfordernis eines Aufenthaltstitels befreit
# Geschlecht                                                          männlich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                                                         0
#        Albanien                                                            0
#        Algerien                                                            0
#        Andorra                                                             0
#        Angola                                                              0
# ...                                                                      ...
# 16077  Zypern                                                              0
#        Ägypten                                                             0
#        Äquatorialguinea                                                    0
#        Äthiopien                                                           0
#        Österreich                                                          0
#
#
# Ausgewählte Aufenthaltstitel
# Geschlecht                   weiblich
# KREISE Staatsangehörigkeit
# 01001  Afghanistan                  0
#        Albanien                     0
#        Algerien                     0
#        Andorra                      0
#        Angola                       0
# ...                               ...
# 16077  Zypern                       0
#        Ägypten                      0
#        Äquatorialguinea             0
#        Äthiopien                    0
#        Österreich                   0
#
# [99008 rows x 26 columns]
