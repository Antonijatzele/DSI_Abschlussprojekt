# %%
from destasis import json2df
import pandas as pd

# %%
df_stat = json2df("12521-0003_Alter")
df_stat = df_stat[df_stat["STAG"] == "2024-12-31"]
df_stat = df_stat[df_stat["GES"] != "%TOTAL%"]
df_stat
# Out:
#        DINSG Deutschland insgesamt   GES Geschlecht        STAG    Stichtag  \
# 103402    DG           Deutschland  GESM   männlich  2024-12-31  31.12.2024
# 103403    DG           Deutschland  GESM   männlich  2024-12-31  31.12.2024
# 103404    DG           Deutschland  GESM   männlich  2024-12-31  31.12.2024
# 103405    DG           Deutschland  GESM   männlich  2024-12-31  31.12.2024
# 103406    DG           Deutschland  GESM   männlich  2024-12-31  31.12.2024
# ...      ...                   ...   ...        ...         ...         ...
# 214753    DG           Deutschland  GESW   weiblich  2024-12-31  31.12.2024
# 214754    DG           Deutschland  GESW   weiblich  2024-12-31  31.12.2024
# 214755    DG           Deutschland  GESW   weiblich  2024-12-31  31.12.2024
# 214756    DG           Deutschland  GESW   weiblich  2024-12-31  31.12.2024
# 214757    DG           Deutschland  GESW   weiblich  2024-12-31  31.12.2024
#
#          LDRGR1 Ländergruppierungen    ALT102 Altersjahre (u1-95m, unbekannt)  \
# 103402   EUROPA              Europa    ALT000                    unter 1 Jahr
# 103403   EUROPA              Europa    ALT001                       1-Jährige
# 103404   EUROPA              Europa    ALT002                       2-Jährige
# 103405   EUROPA              Europa    ALT003                       3-Jährige
# 103406   EUROPA              Europa    ALT004                       4-Jährige
# ...         ...                 ...       ...                             ...
# 214753  %TOTAL%           Insgesamt    ALT092                      92-Jährige
# 214754  %TOTAL%           Insgesamt    ALT093                      93-Jährige
# 214755  %TOTAL%           Insgesamt    ALT094                      94-Jährige
# 214756  %TOTAL%           Insgesamt  ALT095UM               95 Jahre und mehr
# 214757  %TOTAL%           Insgesamt     ALTNN                 Alter unbekannt
#
#         Value
# 103402  21910
# 103403  31925
# 103404  35430
# 103405  38820
# 103406  39515
# ...       ...
# 214753   2740
# 214754   1995
# 214755   1840
# 214756   6835
# 214757      0
#
# [7954 rows x 11 columns]

# %%
df_csv = df_stat[["Ländergruppierungen", "GES", "ALT102", "Value"]]
df_csv.to_csv("alterspyramide.csv")
