# %%
from destasis import json2df

# %%
df = json2df("12511-0019")

# %%
df.head()
# Out:
#     GES Geschlecht    STAEW1 Erwerbsarten der deutschen Staatsangehörigkeit  \
# 0  GESM   männlich  EINBUERG                                 Einbürgerungen
# 1  GESM   männlich  EINBUERG                                 Einbürgerungen
# 2  GESM   männlich  EINBUERG                                 Einbürgerungen
# 3  GESM   männlich  EINBUERG                                 Einbürgerungen
# 4  GESM   männlich  EINBUERG                                 Einbürgerungen
#
#    JAHR  Jahr DLANDU Bundesländer und Ausland STAAG6 Staatsangehörigkeit  \
# 0  2008  2008     08        Baden-Württemberg  ST287             Ägypten
# 1  2008  2008     08        Baden-Württemberg  ST274    Äquatorialguinea
# 2  2008  2008     08        Baden-Württemberg  ST225           Äthiopien
# 3  2008  2008     08        Baden-Württemberg  ST423         Afghanistan
# 4  2008  2008     08        Baden-Württemberg  ST121            Albanien
#
#    Value
# 0     31
# 1      0
# 2     19
# 3     58
# 4     13
